# %% [markdown]
# <h1 style="color: salmon">Exploratory Data Analysis</h1>
# This is very important as I need to understand and like have a brief look into what the dataset has before deep dive into it.

# %%
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("Datasets/bank_transactions_data_2.csv", encoding="utf-8")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 6
#       3 import seaborn as sns
#       4 import matplotlib.pyplot as plt
# ----> 6 df = pd.read_csv("Datasets/bank_transactions_data_2.csv", encoding="utf-8")
#
# File c:\Users\Admin\Desktop\BankFraudML\.venv\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df.head()

# %%
df.columns.to_list()

# %%
print(df.shape)
# total entries, no of cols/features

# %% [markdown]
# ## Anomoly Discorver

# %%
# Occupation-Based Spending Distribution

plt.figure(figsize=(8, 6))
sns.boxplot(data=df, x="CustomerOccupation", y="TransactionAmount")
plt.title("Occupation-Based Spending Distribution")
plt.show()

# %%
# Age group / transaction amount

def ageGroup(age):
    if age < 20:
        return "teen"
    elif 20 <= age < 40:
        return "working_age"
    elif 40 <= age <= 60:
        return "middle_age"
    elif age > 60:
        return "senior"
    
df["Age_Group"] = df["CustomerAge"].apply(ageGroup)
df.head()

sns.boxplot(data=df, x="Age_Group", y="TransactionAmount")
plt.title("Boxplot of transaction amount per age group")
plt.show()

# %%
# Transactions per type
sns.countplot(data=df, x="TransactionType")
plt.title("Count of no of transaction types used")
plt.show()

# %%
# Login Attemps for Age Group
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x="Age_Group", hue="LoginAttempts")
plt.title("Count of login attempts for age group")
plt.show()

# %%
# DeviceID and IPAddresses per account id
# 495 acc id with more than 2 device id
device_counts = df.groupby('AccountID')['DeviceID'].nunique().reset_index()
print(device_counts)
ip_add_counts = df.groupby('AccountID')['IP Address'].nunique().reset_index()
print(ip_add_counts)
